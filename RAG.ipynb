# %%
# !pip install langchain-docling

# %%
import ollama
model="llama3:8b"
def ask_llm(inp):
    rules=f"""
    You are a financial assistance working at bankX,A banking company.You will need to respond to customer on their queries.
    The input given is {inp}
    """
    response=ollama.chat(
        model=model,
        messages=[
            {
            "role":"user",
            "content":rules,
        }
      ],
        stream=True
    )
    for res in response:
        print(res["message"]["content"],end = "",flush = True)

# %%
print("Hello",end = "")
print("world")
# Out:
# Helloworld

# %%
while True:
        inp=input("Enter query")
        ask_llm(inp)
# Out:
# Enter query Hey whats my name ?
# Hello there! I'm happy to help you with your query. Since you're asking about your name, I'd like to check our records real quick.
#
# Can you please confirm your account number or provide some identifying information so I can look up your profile? That way, I can give you a more accurate answer.
# Enter query how can i get the loan
# Thank you for reaching out to BankX! I'd be happy to help you with your inquiry about getting a loan.
#
# To get started, could you please share some more details about what type of loan you're interested in? Are you looking for a personal loan, mortgage, auto loan, or something else?
#
# Also, what's the purpose of the loan? Are you looking to purchase a new property, consolidate debt, cover unexpected expenses, or fund a big project?
#
# Once I have a better understanding of your needs and goals, I can guide you through our loan options and help you determine which one best suits your situation.
#
# ...

# %%
import ollama
from langchain_docling.loader import DoclingLoader
FILE_PATH = r"C:/Users/HP/OneDrive/Desktop/uht/Introduction_to_Artificial_Intelligence.pdf"
loader = DoclingLoader(FILE_PATH)
docs = loader.load()
# Out:
# ...
# The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# The plugin langchain_docling will not be loaded because Docling is being executed with allow_external_plugins=false.
# [INFO] 2026-06-13 10:04:47,479 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-06-13 10:04:47,562 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-06-13 10:04:47,566 [RapidOCR] main.py:65: Using C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.onnx
# [INFO] 2026-06-13 10:04:47,964 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

file_path = r"C:\Users\HP\OneDrive\Desktop\uht\Introduction_to_Artificial_Intelligence.pdf"

loader = PyPDFLoader(file_path)
docs = loader.load()

print(docs[0].page_content[:500])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21760\2110688725.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# Introduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can
# perform tasks that normally require human intelligence. These tasks include learning from data,
# understanding language, recognizing patterns, solving problems, and making decisions.
# Modern AI is used in many areas such as virtual assistants, recommendation systems, healthcare,
# transportation, and education. Machine learning, a major branch of AI, enables comput

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=60)
texts = text_splitter.split_documents(docs)

print(texts[0])
# Out:
# page_content='Introduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can' metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-12T06:06:33+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-06-12T06:06:33+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'C:\\Users\\HP\\OneDrive\\Desktop\\uht\\Introduction_to_Artificial_Intelligence.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings =HuggingFaceEmbeddings(model_name="BAAI/bge-large-en-v1.5")
# Out:
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]

# %%
from langchain_chroma import Chroma

vector_store=Chroma(
    collection_name="sample_RAG",
    embedding_function=embeddings,
    persist_directory="./chroma_langchain_db",
)

# %%
from langchain_community.vectorstores.utils import filter_complex_metadata
texts = filter_complex_metadata(texts)
vector_store.add_documents(texts)
# Out:
# ['6eb49806-04a9-41ac-bd69-1c775eb14816',
#  '4c89a290-5a6b-4572-8886-1294cf280cc4',
#  '8e6172cb-1e5a-4906-bea7-00049cd57c8d',
#  '8994be64-05b4-4c3e-8367-17e616eb76a9',
#  'e848475c-a522-4f79-adbe-ed99c89a47a2']

# %%
vector_store._collection.count()
# Out:
# 15

# %%
from langchain_community.vectorstores.utils import filter_complex_metadata
texts=filter_complex_metadata(texts)
texts[0]
# Out:
# Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-12T06:06:33+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-06-12T06:06:33+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'C:\\Users\\HP\\OneDrive\\Desktop\\uht\\Introduction_to_Artificial_Intelligence.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Introduction to Artificial Intelligence\nArtificial Intelligence (AI) is a field of computer science focused on creating systems that can')

# %%
vector_store.add_documents(texts)
# Out:
# ['26ec5e0b-f065-45d8-88fb-153c30127ef6',
#  '0a0617c0-49b7-4683-a8f3-b469169d2142',
#  '0abd3056-c9a3-43bb-937d-6872ab26ccd3',
#  '9fba74a1-95b4-41b2-8b8c-2bc561aac135',
#  'd260dcf6-3102-4aed-82d8-e4435c91b05d']

# %%
vector_store._collection.get(ids=['da30f2b4-10cd-484a-8abf-6ab47ac65893'],include=["embeddings","documents"])
# Out:
# {'ids': ['da30f2b4-10cd-484a-8abf-6ab47ac65893'],
#  'embeddings': array([[ 0.00659348,  0.0121582 , -0.0012824 , ...,  0.01073442,
#          -0.03194325,  0.00975933]], shape=(1, 1024)),
#  'documents': ['Introduction to Artificial Intelligence\nArtificial Intelligence (AI) is a field of computer science focused on creating systems that can'],
#  'uris': None,
#  'included': ['embeddings', 'documents'],
#  'data': None,
#  'metadatas': None}

# %%
retriever = vector_store.as_retriever()

# %%
query="what is AI"
retriever_docs=retriever.invoke(query)
context="/n/n".join([doc.page_content for doc in retriever_docs])
print(context)
# Out:
# Introduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can/n/nIntroduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can/n/nIntroduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can/n/nIntroduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can

# %%
docs=retriever.invoke("what is major branch of AI")
print(docs)
# Out:
# [Document(id='79a2a91d-e936-4d2f-a4c1-5c386363b54d', metadata={'trapped': '/False', 'source': 'C:\\Users\\HP\\OneDrive\\Desktop\\uht\\Introduction_to_Artificial_Intelligence.pdf', 'author': '(anonymous)', 'total_pages': 1, 'subject': '(unspecified)', 'moddate': '2026-06-12T06:06:33+00:00', 'producer': 'ReportLab PDF Library - (opensource)', 'creationdate': '2026-06-12T06:06:33+00:00', 'page': 0, 'creator': '(unspecified)', 'title': '(anonymous)', 'keywords': '', 'page_label': '1'}, page_content='Introduction to Artificial Intelligence\nArtificial Intelligence (AI) is a field of computer science focused on creating systems that can'), Document(id='da30f2b4-10cd-484a-8abf-6ab47ac65893', metadata={'subject': '(unspecified)', 'producer': 'ReportLab PDF Library - (opensource)', 'trapped': '/False', 'author': '(anonymous)', 'keywords': '', 'title': '(anonymous)', 'creationdate': '2026-06-12T06:06:33+00:00', 'source': 'C:\\Users\\HP\\OneDrive\\Desktop\\uht\\Introduction_to_Artificial_Intell
# ...

# %%
prompt=f"""you are an intelligent RAG assistant .Answer the users questions based on any topic
context:
  {context}

question:
  {query} 
  """

# %%
print(query)
print(context)
ask_llm(prompt)
# Out:
# what is AI
# Introduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can/n/nIntroduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can/n/nIntroduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can/n/nIntroduction to Artificial Intelligence
# Artificial Intelligence (AI) is a field of computer science focused on creating systems that can
# Hello
#  there
# !
#  As
#  a
#  financial
#  assistance
#  at
#  Bank
# X
# ,
#  I
# 'm
#  happy
#  to
#  help
#  you
#  with
#  your
#  query
#  about
#  Artificial
#  Intelligence
# .
#
#
#
# Art
# ificial
#  Intelligence
# ,
#  or
#  AI
#  for
#  short
# ,
#  refers
#  to
#  the
#  development
#  of
#  computer
#  systems
#  that
#  can
#  perform
#  tasks
#  that
#  would
#  typically
#  require
#  human
# ...
